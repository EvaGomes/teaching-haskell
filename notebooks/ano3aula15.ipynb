-- %% [markdown]
-- © <b>2020-2024 ENSICO.</b> Todos os direitos reservados. <img src="../assets/copyright-icons.png" style="max-height:2em" />

-- %% [markdown]
-- <hr>
-- <span style="color:darkblue"> ⚠️ <b>IMPORTANTE</b></span>: <b>CORRE A CAIXA DE CÓDIGO SEGUINTE</b> para preparar a página.</span>

-- %%
import Prelude()
:opt no-lint
:l scripts/ensico.hs
done

-- %% [markdown]
-- <hr>

-- %% [markdown]
-- # Ficha 5
-- ## Página 1

-- %% [markdown]
-- ---
--
-- Observa a instrução de declaração do tipo `Aluno`.
-- <br>As 6 **instruções de criação de dados** de tipo `Aluno` têm erros; **corrige-as**.

-- %%
data Aluno = Aluno { nome :: String, idade :: Int, gostaDeEspinafres :: Bool, coresFavoritas :: [String] }

-- %%
aluno1 = "Armindo" 13 False ["amarelo","azul"]

-- %%
aluno2 = Aluno "Carlos" 13 True

-- %%
aluno3 = Aluno "Joca" 11 True "amarelo"

-- %%
aluno4 = Aluno Vicky 12 True []

-- %%
aluno5 = Aluno 13 "Xico" False ["verde","branco"]

-- %%
aluno6 = Aluno "Zuleica",11,True,["rosa","roxo","azul"]

-- %% [markdown]
-- ---
--
-- Qual destas instruções de declaração do tipo `Animal` está **bem escrita**?
-- <br>**Sublinha os erros** nas outras 5 instruções.

-- %%
data Animal = Animal { Espécie :: String, TemDentes :: Bool, voa :: Bool, Número_de_olhos :: Int }

-- %%
Data Animal = Animal { espécie :: String, temDentes :: Bool, voa :: Bool, número_de_olhos :: Int }

-- %%
data animal = animal { espécie :: String, temDentes :: Bool, voa :: Bool, número_de_olhos :: Int }

-- %%
data Animal = Animal { espécie :: string, temDentes :: bool, voa :: bool, número_de_olhos :: int }

-- %%
data Animal = Animal { espécie : String, temDentes : Bool, voa : Bool, número_de_olhos : Int }

-- %%
data Animal = Animal { espécie :: String, temDentes :: Bool, voa :: Bool, número_de_olhos :: Int }

-- %% [markdown]
-- ## Página 2

-- %% [markdown]
-- Observa o tipo `Compra` e a lista `compras`.

-- %%
data Compra = Compra { produto :: String,
                       preço :: Double,
                       expiraHoje :: Bool } deriving (Eq,Ord,Show)

-- %%
compras = [Compra "pão" 1.89 False, Compra "sumo" 0.79 False, Compra "leite" 1.20 False, Compra "ovos" 2.50 True, Compra "queijo" 3.40 False, Compra "fiambre" 2.30 False, Compra "manteiga" 1.50 False, Compra "iogurte" 0.61 False, Compra "café" 3.00 False, Compra "arroz" 1.10 False, Compra "massa" 0.90 False, Compra "azeite" 4.49 False, Compra "farinha" 0.80 False, Compra "fermento" 0.40 False, Compra "salsichas" 2.20 True, Compra "alface" 1.00 False, Compra "kiwis" 1.80 False, Compra "brócolos" 1.50 False, Compra "cenouras" 0.72 False, Compra "batatas" 1.17 False, Compra "cebolas" 0.90 False, Compra "alho" 0.61 False, Compra "pimentos" 0.85 False, Compra "uvas" 2.00 True, Compra "cereais" 2.40 False, Compra "frango" 5.00 False, Compra "atum" 1.50 False, Compra "ervilhas" 0.80 False, Compra "caderno" 0.75 False]

-- %% [markdown]
-- **Traduz** as seguintes frases para instruções de Jupyter.

-- %% [markdown]
-- <div style="margin-top:1rem; margin-bottom:0px"><i>Há mais de 30 compras na lista <code>compras</code>.</i></div>

-- %%
-- Out:
-- False

-- %% [markdown]
-- <div style="margin-top:30px; margin-bottom:0px"><i>Qual é o sétimo elemento da lista <code>compras</code>?</i></div>

-- %%
-- Out:
-- Compra {produto = "manteiga", preço = 1.5, expiraHoje = False}

-- %% [markdown]
-- <div style="margin-top:30px; margin-bottom:0px"><i>Ordena a lista <code>compras</code> por ordem dos preços.</i></div>

-- %%
-- Out:
-- [Compra {produto = "fermento", preço = 0.4, expiraHoje = False},Compra {produto = "iogurte", preço = 0.61, expiraHoje = False},Compra {produto = "alho", preço = 0.61, expiraHoje = False},Compra {produto = "cenouras", preço = 0.72, expiraHoje = False},Compra {produto = "caderno", preço = 0.75, expiraHoje = False},Compra {produto = "sumo", preço = 0.79, expiraHoje = False},Compra {produto = "farinha", preço = 0.8, expiraHoje = False},Compra {produto = "ervilhas", preço = 0.8, expiraHoje = False},Compra {produto = "pimentos", preço = 0.85, expiraHoje = False},Compra {produto = "massa", preço = 0.9, expiraHoje = False},Compra {produto = "cebolas", preço = 0.9, expiraHoje = False},Compra {produto = "alface", preço = 1.0, expiraHoje = False},Compra {produto = "arroz", preço = 1.1, expiraHoje = False},Compra {produto = "batatas", preço = 1.17, expiraHoje = False},Compra {produto = "leite", preço = 1.2, expiraHoje = False},Compra {produto = "manteiga", preço = 1.5, expiraHoje = False},Compr
-- ...

-- %% [markdown]
-- <div style="margin-top:30px; margin-bottom:0px"><i>A soma dos preços da lista <code>compras</code> é inferior a 50.</i></div>

-- %%
-- Out:
-- True

-- %% [markdown]
-- <div style="margin-top:30px; margin-bottom:0px"><i>O último produto da lista <code>compras</code> começa pela letra <code>'c'</code>.</i></div>

-- %%
-- Out:
-- True
