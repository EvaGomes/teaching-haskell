-- %% [markdown]
-- © <b>2020-2024 ENSICO.</b> Todos os direitos reservados. <img src="../assets/copyright-icons.png" style="max-height:2em" />

-- %% [markdown]
-- <hr>
-- <span style="color:darkblue"> ⚠️ <b>IMPORTANTE</b></span>: <b>CORRE A CAIXA DE CÓDIGO SEGUINTE</b> para preparares esta página!
-- <br><span style="color:gray">(Para isso, clica na caixa e depois carrega no botão <img src="../assets/play.PNG" /> que está na barra acima).</span>

-- %%
import Prelude()
:opt no-lint
:l scripts/ensico.hs
done

-- %% [markdown]
-- ---
--
-- # Transformações sobre Números e Transformação `map`
-- > **Computação - Ano 2 - Aula 4** <br>
-- > © 2020-2024 ENSICO. Todos os direitos reservados

-- %% [markdown]
-- <img src="attachment:9bdab040-7c3a-49a0-9665-416aba14fe38.png" style="max-width:min(800px,100%)" />

-- %%
25 |> (+12)
-- Out:
-- 37

-- %% [markdown]
-- <img src="attachment:ab249a4c-edf9-4c71-b756-d08deb54cbc8.png" style="max-width:min(800px,100%)" />

-- %%
11 |> (*8)
-- Out:
-- 88

-- %% [markdown]
-- <img src="attachment:6f39389a-bb03-4e91-b515-8942fa2c9cd4.png" style="max-width:min(800px,100%)" />

-- %% [markdown]
-- Atividade 1.a

-- %%
3 |> (*9)

-- %% [markdown]
-- Atividade 1.b

-- %%
5 |> (*10) |> (+2)

-- %% [markdown]
-- Atividade 1.c

-- %%
5 |> (+2) |> (*10)

-- %% [markdown]
-- Atividade 2

-- %%
121 |> ............

-- %% [markdown]
-- <br>
-- <hr>
-- <h2>Transformação <code>map</code></h2>
-- <img src="attachment:23257719-e09f-44df-9434-226390eab062.png" style="max-width:min(800px,100%)" />
-- <img src="attachment:2c64ee47-f32a-48d9-92dc-bbb0d2c0319d.png" style="max-width:min(800px,100%)" />

-- %%
[2,1,1,1,1,2,3,4,20,45,6,13,22,17,12,10,2,1,19,15,19,55,4,19,19,13,11,10,9,5,5,2,3,3,4,32,35,3,2,22,4,2,1,4,4,3,49,39,29,19,10,1,2,7,19,19,4,8,18,19,19,19,2,5,3,1,1,1,2,10,30,55,20,1,3,2,16,14,14,12,11,12,2,1,1,8,8,8,8,8,8,4,5,3,31,3,45,40,50,50,2,3,3,3,1,3,8] |> .........

-- %% [markdown]
-- <br>
-- <br>
-- <br>
-- Que rápido!! 🙀🙀

-- %% [markdown]
-- <img src="attachment:d43c3f2c-1135-4045-ac77-8563a49ae782.png" style="max-width:min(800px,100%)" />

-- %%
[10,9,8] |> map (*3)

-- %%
[3,1,3,2,7] |> map (+5)

-- %%
[2,1,0] |> map (*10)

-- %%
[3,5,1] |> map (+1) |> map (*3)
