-- %% [markdown]
-- © <b>2020-2025 ENSICO.</b> Todos os direitos reservados. <img src="../assets/copyright-icons.png" style="max-height:2em" />

-- %% [markdown]
-- <hr>
-- <span style="color:darkblue"> ⚠️ <b>IMPORTANTE</b></span>: <b>CORRE A CAIXA DE CÓDIGO SEGUINTE</b> para preparares esta página!
-- <br/><span style="color:gray">(Para isso, clica na caixa abaixo e depois carrega no botão <img src="../assets/play.PNG" /> que está na barra acima).</span>

-- %%
import Prelude()
:opt no-lint
:l scripts/ensico.hs
done

-- %% [markdown]
-- ---
--
-- # Pares
-- > **Computação - Ano 2 - Aula 14**<br>
-- > © 2020-2025 ENSICO. Todos os direitos reservados

-- %% [markdown]
-- ---
--
-- <br>
-- <img src="attachment:ccbfae2e-a7cc-4a36-b735-dc3ef4bad9c9.png" style="max-width:min(1200px,100%)">
-- <img src="attachment:b8c63c7f-3e75-48ef-8ea7-0c0c13637481.png" style="max-width:min(1200px,100%)">
-- <img src="attachment:809d7b20-7f1c-46ca-831d-52dce1d21bcc.png" style="max-width:min(1200px,100%)">
-- <img src="attachment:21eb5d59-5809-44af-bbd2-cdcfa037f04f.png" style="max-width:min(1200px,100%)">

-- %% [markdown]
-- <br>
--
-- ---
--
-- ## Vamos começar por **registar os produtos** que possui na loja!
-- <img src="attachment:5c7269f3-e42a-453e-8e4a-a50b78e7c4a7.png" style="max-width:min(1000px,100%)">

-- %% [markdown]
-- ### <img src="attachment:675890ef-cecb-4fa1-bc8f-5e8decf8d3ce.png" style="max-width:min(1000px,100%)">

-- %%
....

-- %% [markdown]
-- <br>

-- %% [markdown]
-- ##### Solução **a)**:

-- %%
["casaco","jeans","blazer","t-shirt","camisa","top","calças","camisola","macacão","vestido","saia","sweat"]

-- %% [markdown]
-- ##### Solução **b)**:

-- %%
inventário = ["casaco","jeans","blazer","t-shirt","camisa","top","calças","camisola","macacão","vestido","saia","sweat"]

-- %% [markdown]
-- <br>
--
-- ---

-- %% [markdown]
-- ## <img src="attachment:9a259ef1-0d18-4662-a838-ab4e7bbcbd16.png" style="max-width:min(1200px,100%)">
-- <img src="attachment:2a0dacfd-cd15-4869-a21b-7e56b0d71e0b.png" style="max-width:min(1200px,100%)">

-- %%
[ "casaco", "jeans", "blazer", "t-shirt", "camisa", "top", "calças", "camisola", "macacão", "vestido", "saia", "sweat"]

-- %% [markdown]
-- <img src="attachment:b38bf9db-f41d-4774-a024-1aed30820c18.png" style="max-width:min(1200px,100%)">

-- %% [markdown]
-- <br><br>
--
-- ## 💡 Ideia
-- <img src="attachment:4db15a47-8a25-4637-aa46-58a026f30317.png" style="max-width:min(1200px,100%)">
-- <br>
-- <br>Experimenta executar a instrução abaixo:

-- %%
inventario = ["casaco", 31, "jeans", 25, "blazer", 11, "t-shirt", 45, "camisa", 37, "top", 3, "calças", 23, "camisola", 55, "macacão", 2, "vestido", 8, "saia", 11, "sweat", 23]

-- %% [markdown]
-- <br><br><br><br>
-- <img src="attachment:28ae9b2a-6e88-4b74-92eb-89c4cfe7f5ab.png" style="max-width:min(1200px,100%)">
-- <br><br><br><br>
-- <img src="attachment:251a5756-ad3b-4f5d-8475-2fecc6e691e0.png" style="max-width:min(1200px,100%)">

-- %% [markdown]
-- Por isso, estas ideias não funcionam:

-- %%
["casaco", 31, "jeans", 25, "blazer", 11, "t-shirt", 45, "camisa", 37, "top", 3, "calças", 23, "camisola", 55, "macacão", 2, "vestido", 8, "saia", 11, "sweat", 23]
-- Out:
-- <interactive>:1:12: error: [GHC-39999]
--     • No instance for ‘Num String’ arising from the literal ‘31’
--     • In the expression: 31
--       In the expression: ["casaco", 31, "jeans", 25, ....]
--       In an equation for ‘it’: it = ["casaco", 31, "jeans", ....]

-- %%
["casaco", "jeans", "blazer", "t-shirt", "camisa", "top", "calças", "camisola", "macacão", "vestido", "saia", "sweat", 31, 25, 11, 45, 37, 3,23, 55, 2, 8, 11, 23]
-- Out:
-- <interactive>:1:118: error: [GHC-39999]
--     • No instance for ‘Num String’ arising from the literal ‘31’
--     • In the expression: 31
--       In the expression: ["casaco", "jeans", "blazer", "t-shirt", ....]
--       In an equation for ‘it’: it = ["casaco", "jeans", "blazer", ....]

-- %%
[ ["casaco",31], ["jeans",25], ["blazer",11], ["t-shirt",45], ["camisa",37], ["top",3], ["calças",23], ["camisola",55], ["macacão",2], ["vestido", 8], ["saia", 11], ["sweat", 23] ]
-- Out:
-- <interactive>:1:13: error: [GHC-39999]
--     • No instance for ‘Num String’ arising from the literal ‘31’
--     • In the expression: 31
--       In the expression: ["casaco", 31]
--       In the expression: [["casaco", 31], ["jeans", 25], ["blazer", 11], ["t-shirt", 45], ....]

-- %% [markdown]
-- <br>
-- <img src="attachment:05a8f273-7253-4afa-b652-e0191e2649a6.png" style="max-width:min(1200px,100%)">
-- <br>
-- <img src="attachment:b5742265-8683-42c4-aebe-c316bc34a867.png" style="max-width:min(1200px,100%)">
-- <br>
-- <img src="attachment:fc4d79c1-bbbc-4155-839a-9ff12b173895.png" style="max-width:min(1200px,100%)">
-- <br>

-- %%
inventário = [ ("casaco",31) , "jeans", "blazer", "t-shirt", "camisa", "top", "calças", "camisola", "macacão", "vestido", "saia", "sweat"]

-- %% [markdown]
-- <img src="attachment:4fc6e98d-b10b-4582-a9e5-d1a84483269d.png" style="max-width:min(1200px,100%)">
