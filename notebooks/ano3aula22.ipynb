-- %% [markdown]
-- © <b>2020-2025 ENSICO.</b> Todos os direitos reservados. <img src="../assets/copyright-icons.png" style="max-height:2em" />

-- %% [markdown]
-- <hr>
-- <span style="color:darkblue"> ⚠️ <b>IMPORTANTE</b></span>: <b>CORRE A CAIXA DE CÓDIGO SEGUINTE</b> para preparar a página.</span>

-- %%
import Prelude()
:opt no-lint
:l scripts/ensico.hs
done

-- %% [markdown]
-- <hr>

-- %% [markdown]
-- # Ficha 7
-- > **Computação - Ano 3 - Aula 22** <br>
-- > © 2020-2025 ENSICO. Todos os direitos reservados

-- %% [markdown]
-- ---
--
-- <br/><br/>

-- %%
li1 = [654,7,1687,3516,89,524,7,2,8596]

-- %%
li2 = ["nascer", "livro", "mar", "antigo", "sem", "cama", "sarilhos", "gigante", "leoa", "grupo", "vento", "sair" ]

-- %% [markdown]
-- Observa as listas acima.
-- <br/>Indica **o resultado** de cada uma das seguintes instruções de filtragem e **completa a descrição** de cada uma.

-- %%
li1 |> filter(\elem -> elem |> even )

-- %% [markdown]
-- ↳ <i>Escolheu os elementos _________________________________________________________________________</i>

-- %%
li1 |> filter(\elem -> elem |> (==7) )

-- %% [markdown]
-- ↳ <i>Escolheu os elementos _________________________________________________________________________</i>

-- %%
li2 |> filter(\elem -> elem |> length |> (<5) )

-- %% [markdown]
-- ↳ <i>Escolheu os elementos _________________________________________________________________________</i>

-- %%
li1 |> filter(\elem -> elem |> (+400) |> (>1000) )

-- %% [markdown]
-- ↳ <i>Escolheu os elementos _________________________________________________________________________</i>

-- %%
li2 |> filter(\elem -> elem |> head |> (=='s') )

-- %% [markdown]
-- ↳ <i>Escolheu os elementos _________________________________________________________________________</i>

-- %%
li2 |> filter(\elem -> elem |> get 1 |> (=='a') )

-- %% [markdown]
-- ↳ <i>Escolheu os elementos _________________________________________________________________________</i>

-- %% [markdown]
-- <br><br>
--
-- ---
--
-- ## Página 2
-- <br>

-- %% [markdown]
-- Observa a **lista de pares** `li3`, onde cada par nos mostra um personagem e quantos dedos tem numa mão.

-- %%
li3 = [ ("Aladino",5), ("Astrobot",3), ("Barbie",5), ("Bart Simpson",4), ("Batman",5), ("Charmander",4),("CR7",5), ("Doctor Doofenshmirtz",4), ("Doraemon",0),("Elsa",5), ("Godzilla",4), ("Inspetor Max",4),("Ladybug",5), ("Luffy",5), ("Mickey",4), ("Moana",5),("Naruto",5), ("Nemo",0), ("OliverTsubasa",5), ("Popeye",5), ("Ratchet",5), ("Shrek",5), ("SpongeBob",4)]

-- %% [markdown]
-- ---
--
-- Escreve **o resultado** de cada instrução seguinte.

-- %%
li3 |> filter(\elem -> elem |> snd |> (==1) )

-- %%
li3 |> filter(\elem -> elem |> fst |> last |> (=='e') )

-- %%
li3 |> filter(\elem -> elem |> snd |> (<4) )
    |> map fst

-- %% [markdown]
-- <br><br>
--
-- ---
--
-- Escreve **a instrução** que nos dá cada resultado seguinte. 🌶🌶🌶

-- %%
li3 |> filter(\elem ->
-- Out:
-- [("Doraemon",0),("Nemo",0)]

-- %%
li3 |>
-- Out:
-- 2

-- %%
li3 |>
-- Out:
-- [("Barbie",5),("Bart Simpson",4),("Batman",5)]

-- %%
li3 |>
-- Out:
-- ["Bart Simpson","Batman","Doraemon"]
