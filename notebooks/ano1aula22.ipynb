-- %% [markdown]
-- © <b>2020-2024 ENSICO.</b> Todos os direitos reservados. <img src="../assets/copyright-icons.png" style="max-height:2em" />

-- %% [markdown]
-- <hr>
-- <span style="color:darkblue"> ⚠️ <b>IMPORTANTE</b></span>: <b>CORRE A CAIXA DE CÓDIGO SEGUINTE</b> antes de começares as tuas experiências!
-- <br><span style="color:gray">(Para isso, clica na caixa e depois carrega no botão <img src="../assets/play.PNG" /> que está na barra acima).</span>

-- %%
import Prelude()
:opt no-lint
:l scripts/ensico.hs
done

-- %% [markdown]
-- ---
--
-- # Listas numéricas e transformações (parte 1)
-- > **Computação - Ano 1 - Aula 22** <br>
-- > © 2020-2024 ENSICO. Todos os direitos reservados

-- %% [markdown]
-- ---
-- <img src="attachment:dfa04ad3-89b0-4d87-8b02-8731638b1363.png" style="max-width:min(800px,100%)" />

-- %% [markdown]
-- ### ➡️ **Listas** (ou **Sequências**)

-- %%
[80,35,123,35,18]

-- %% [markdown]
-- * #### Podemos colocar espaços entre as vírgulas e os números, não interfere:

-- %%
[80, 35, 123, 35, 18]

-- %%
[80  ,    35,123, 35,  18]

-- %% [markdown]
-- * #### Mas o que acontece se nos esquecermos dos parênteses **`[ ... ]`**?

-- %%
80,35,123,35,18

-- %% [markdown]
-- * #### O que acontece se colocarmos pontos **`.`** em vez de vírgulas **`,`**?

-- %%
[80.35.123.35.18]

-- %% [markdown]
-- #### **Conclusão:** Temos de escrever tudo direitinho, com **parênteses** e **vírgulas**! 😃

-- %% [markdown]
-- ---
--
-- <img src="attachment:dbe79ecc-18dc-4bb4-97ff-ed3300813ba0.png" style="max-width:min(800px,100%)" />
--
-- ### ➡️ **Soma** de todos os números de uma lista:

-- %%
[80, 35, 123, 35, 18] |> sum

-- %% [markdown]
-- ---
--
-- <img src="attachment:926c5c43-ac78-45da-8f66-1f4e31986e7e.png" style="max-width:min(800px,100%)" />

-- %%
[527, 413, ...]

-- %% [markdown]
-- <img src="attachment:05906daf-416a-4edf-a812-84d9785391f0.png" style="max-width:min(800px,100%)" />

-- %%
[527, 413, 377, 367, 356] ...

-- %% [markdown]
-- ---
--
-- <img src="attachment:5417eb1b-fcc8-49c3-91c3-6d129adc3593.png" style="max-width:min(800px,100%)" />
--
-- ### ➡️ Número **máximo** que ocorre numa lista:

-- %%
[80, 35, 123, 35, 18] ...

-- %% [markdown]
-- ---
-- <img src="attachment:b6bdd14a-9cd6-48be-8773-1af773ed3f47.png" style="max-width:min(800px,100%)" />

-- %% [markdown]
-- ### **a)** Lista:

-- %%
...

-- %% [markdown]
-- <img src="attachment:ddaa79c1-bdde-4cb3-bf1f-bba1d33617b9.png" style="max-width:min(800px,100%)" />

-- %% [markdown]
-- ### **b.1)** Soma:

-- %%
[130, 859, 18, 250, 18, 250] ...

-- %% [markdown]
-- ### **b.2)** Máximo:

-- %%
[130, 859, 18, 250, 18, 250] ...

-- %% [markdown]
-- <img src="attachment:fae5bab8-e80a-481a-8eae-547622ca0b0e.png" style="max-width:min(800px,100%)" />

-- %% [markdown]
-- ### **b.3)** Ordenar de forma crescente:

-- %%
[130, 859, 18, 250, 18, 250] ...

-- %% [markdown]
-- ### **b.4)** Eliminar elementos repetidos:

-- %%
[130, 859, 18, 250, 18, 250] ...

-- %% [markdown]
-- <img src="attachment:a31bd7cc-9410-4700-949f-25bdd8d792b1.png" style="max-width:min(800px,100%)" />

-- %% [markdown]
-- ### **c)** A transformação **`reverse`**:

-- %%
[130, 859, 18, 250, 18, 250] ...

-- %% [markdown]
-- ### **d)** A transformação **`length`**:

-- %%
[130, 859, 18, 250, 18, 250] ...
