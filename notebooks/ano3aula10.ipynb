-- %% [markdown]
-- © <b>2020-2024 ENSICO.</b> Todos os direitos reservados. <img src="../assets/copyright-icons.png" style="max-height:2em" />

-- %% [markdown]
-- <hr>
-- <span style="color:darkblue"> ⚠️ <b>IMPORTANTE</b></span>: <b>CORRE A CAIXA DE CÓDIGO SEGUINTE</b> para preparar a página.</span>

-- %%
import Prelude()
:opt no-lint
:l scripts/ensico.hs
done
-- Out:
-- Feito!

-- %% [markdown]
-- <hr>

-- %% [markdown]
-- # Ficha 4
-- ## Página 1

-- %% [markdown]
-- ---
-- Escreve os **resultados** das seguintes instruções.

-- %%
56348 |> (>50000)
-- Out:
-- True

-- %%
56348 |> even
-- Out:
-- True

-- %%
56348 |> odd
-- Out:
-- False

-- %%
56348 |> (+2) |> (==56350)
-- Out:
-- True

-- %%
"Só funciona com números?" |> length |> (>10)
-- Out:
-- True

-- %%
"Só funciona com números?" |> nub |> (=="Sófuncio")
-- Out:
-- False

-- %%
"Só funciona com números?" |> last |> (=='s')
-- Out:
-- False

-- %%
["morangos","com","açúcar"] |> length |> (>5)
-- Out:
-- False

-- %%
[45,46,47,48,49] |> map even
-- Out:
-- [False,True,False,True,False]

-- %%
[45,46,47,48,49] |> map (<47)
-- Out:
-- [True,True,False,False,False]

-- %% [markdown]
-- ---
-- Observa a lista `li` e **traduz cada proposição** para a língua do Jupyter.

-- %%
li = [ 576704, 576704, 16, 804, 375, 133419, 148954, 402455 ]

-- %% [markdown]
-- <div style="margin-top:1rem; padding-top:12px; margin-bottom:0"><small>P:</small> <i>A lista <code>li</code> não tem 400 números.</i></div>

-- %%
li |> length |> (/=400)
-- Out:
-- True

-- %% [markdown]
-- <div style="margin-top:1rem; padding-top:12px; margin-bottom:0"><small>P:</small> <i>O primeiro número da lista <code>li</code> é o <code>57</code>.</i></div>

-- %%
li |> get 0 |> (==57)
-- Out:
-- False

-- %% [markdown]
-- <div style="margin-top:1rem; padding-top:12px; margin-bottom:0"><small>P:</small> <i>O sexto número da lista <code>li</code> é par.</i></div>

-- %%
li |> get 5 |> even
-- Out:
-- False

-- %% [markdown]
-- ## Página 2

-- %% [markdown]
-- Observa a seguinte lista de pares, que mostra produtos e os seus respetivos preços.

-- %%
compras = [ ("pão", 1.89), ("sumo", 0.79), ("leite", 1.20), ("ovos", 2.50), ("queijo", 3.40), ("fiambre", 2.30), ("manteiga", 1.50), ("iogurte", 0.61), ("café", 3.00), ("arroz", 1.10), ("massa", 0.90), ("azeite", 4.49), ("farinha", 0.80), ("fermento", 0.40), ("salsichas", 2.20), ("alface", 1.00), ("kiwis", 1.80), ("brócolos", 1.50), ("cenouras", 0.72), ("batatas", 1.17), ("cebolas", 0.90), ("alho", 0.61), ("pimentos", 0.85), ("uvas", 2.00), ("cereais", 2.40), ("frango", 5.00), ("atum", 1.50), ("ervilhas", 0.80), ("caderno", 0.75) ]

-- %% [markdown]
-- <br>
-- Escreve as <b>instruções de Jupyter</b> que traduzem cada uma das quatro proposições lógicas que se seguem.

-- %% [markdown]
-- <div style="margin-top:1rem; padding-top:12px; margin-bottom:0"><small>P:</small> <i>Há mais de 30 pares na lista <code>compras</code>.</i></div>

-- %%
compras |> length |> (>30)
-- Out:
-- False

-- %% [markdown]
-- <div style="margin-top:1rem; padding-top:12px; margin-bottom:0"><small>P:</small> <i>O quinto elemento da lista <code>compras</code> é <code>("sumo",0.79)</code>.</i></div>

-- %%
compras |> get 4 |> (==("sumo",0.79))
-- Out:
-- False

-- %% [markdown]
-- <div style="margin-top:1rem; padding-top:12px; margin-bottom:0"><small>P:</small> <i>A soma dos preços da lista <code>compras</code> é inferior a 50.</i></div>

-- %%
compras |> map snd |> sum |> (<50)
-- Out:
-- True

-- %% [markdown]
-- <div style="margin-top:1rem; padding-top:12px; margin-bottom:0"><small>P:</small> <i>O último produto da lista <code>compras</code> começa pela letra <code>'c'</code>. &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; &nbsp; 🌶🌶🌶</i></div>

-- %%
compras |> last |> fst |> head |> (=='c')
-- Out:
-- True

-- %% [markdown]
-- <br>
-- <hr>
-- Escreve o <b>resultado</b> da segunda instrução.

-- %%
mini_lista_de_compras = ["pimentos","fruta","cereais","frango", "queijo","fiambre","iogurte","arroz","sumo","leite", "farinha"]

-- %%
mini_lista_de_compras |> map head |> map (=='f')
-- Out:
-- [False,True,False,True,False,True,False,False,False,False,True]
