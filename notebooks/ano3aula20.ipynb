-- %% [markdown]
-- © <b>2020-2025 ENSICO.</b> Todos os direitos reservados. <img src="../assets/copyright-icons.png" style="max-height:2em" />

-- %% [markdown]
-- <hr>
-- <span style="color:darkblue"> ⚠️ <b>IMPORTANTE</b></span>: <b>CORRE A CAIXA DE CÓDIGO SEGUINTE</b> para preparar a página.</span>

-- %%
import Prelude()
:opt no-lint
:l scripts/ensico.hs
done

-- %% [markdown]
-- <hr>

-- %% [markdown]
-- # Ficha 6
-- ## Correção do Trabalho de Grupo 4 (da Aula 17, prática)
-- > **Computação - Ano 3 - Aula 20** <br>
-- > © 2020-2025 ENSICO. Todos os direitos reservados

-- %% [markdown]
-- ###
--
-- ---

-- %% [markdown]
-- **Portugal** está dividido em **20 distritos** (18 continentais e 2 regiões autónomas nas ilhas).
-- Cada distrito divide-se em **municípios** e cada município divide-se em **freguesias**.
--
-- Abaixo encontras a instrução de declaração do tipo `Município` e uma lista com elementos desse tipo.

-- %%
data Município = Município { nome :: String, hab :: Int, distrito :: String, freg :: Int } deriving (Eq,Ord,Show)

-- %%
municipios = [Município "Abrantes" 39325 "Santarém" 13, Município "Aguiar da Beira" 5473 "Guarda" 10, Município "Alandroal" 5843 "Évora" 4, Município "Albergaria-a-Velha" 25252 "Aveiro" 6, Município "Albufeira" 40828 "Faro" 4, Município "Alcanena" 13868 "Santarém" 7, Município "Alcobaça" 56676 "Leiria" 13, Município "Alcochete" 17569 "Setúbal" 3, Município "Alcoutim" 2917 "Faro" 4, Município "Alcácer do Sal" 13046 "Setúbal" 4, Município "Alenquer" 43267 "Lisboa" 11, Município "Alfândega da Fé" 5104 "Bragança" 12, Município "Alijó" 11942 "Vila Real" 14, Município "Aljezur" 5884 "Faro" 4, Município "Aljustrel" 9257 "Beja" 4, Município "Almada" 174030 "Setúbal" 5, Município "Almeida" 7228 "Guarda" 16, Município "Almeirim" 23376 "Santarém" 4, Município "Almodôvar" 7449 "Beja" 6, Município "Alpiarça" 7702 "Santarém" 1, Município "Alter do Chão" 3562 "Portalegre" 4, Município "Alvaiázere" 7287 "Leiria" 5, Município "Alvito" 2504 "Beja" 2, Município "Amadora" 175135 "Lisboa" 6, Município "Amarante" 56217 "Porto" 26, ...................................., Município "Águeda" 47729 "Aveiro" 11, Município "Évora" 56596 "Évora" 12, Município "Ílhavo" 38598 "Aveiro" 4, Município "Óbidos" 11772 "Leiria" 7]

-- %% [markdown]
-- Sobre cada `Município` encontras:
-- - `nome`- o seu nome,
-- - `hab`- a quantidade de pessoas que habitam nesse município,
-- - `distrito`- o distrito ao qual pertence, e
-- - `freg`- o número de freguesias que o compõem.

-- %% [markdown]
-- ---
--
-- **Quantos** municípios tem a lista `municipios`?

-- %%
-- Out:
-- 308

-- %% [markdown]
-- ---
-- Qual é o **35º** elemento da lista municipios?

-- %%
-- Out:
-- Município {nome = "Arronches", hab = 3119, distrito = "Portalegre", freg = 3}

-- %% [markdown]
-- ---
-- Soma os números de freguesias de todos os municípios para descobrires **quantas freguesias** tem Portugal.

-- %%
-- Out:
-- 3092

-- %% [markdown]
-- ---
-- Obtém a **lista de nomes** dos municípios, **ordenada por número de habitantes**.
-- <p style="font-size:small">
--     <u>Pista 1:</u> Começa por ordenar os municípios desde o que tem menos habitantes ao que tem mais.
-- </p>

-- %%
-- Out:
-- ["Corvo","Lajes das Flores","Barrancos","Santa Cruz das Flores","Alvito","Mour\227o","Porto Moniz","Alcoutim","Penedono","Arronches","Castanheira de P\234ra","Monforte","S\227o Roque do Pico","Castelo de Vide","Fronteira","Manteigas","Vila de Rei","Marv\227o","Vila Velha de R\243d\227o","Alter do Ch\227o","Crato","Calheta de S\227o Jorge","Freixo de Espada \224 Cinta","Pedr\243g\227o Grande","Sardoal","Const\226ncia","Gavi\227o","G\243is","Santa Cruz da Graciosa","Mes\227o Frio","Pampilhosa da Serra","Avis","Vimioso","Lajes do Pico","Cuba","Nordeste","Mora","Fornos de Algodres","Sousel","Alf\226ndega da F\233","Vila Nova de Paiva","M\234da","Vila do Bispo","Ourique","Velas","Goleg\227","Aguiar da Beira","Porto Santo","Vila do Porto","Sernancelhe","Penamacor","Oleiros","S\227o Vicente","Viana do Alentejo","Boticas","Alandroal","Aljezur","Vidigueira","Mur\231a","Penela","Monchique","Madalena","Figueir\243 dos Vinhos","Figueira de Castelo Rodrigo","Armamar","Povoa\231\227o","Tabua\231o
-- ...

-- %% [markdown]
-- ---
-- Obtém a **lista dos 20 distritos, ordenada**.

-- %%
-- Out:
-- ["Aveiro","Beja","Braga","Bragan\231a","Castelo Branco","Coimbra","Faro","Guarda","Leiria","Lisboa","Portalegre","Porto","Regi\227o Aut\243noma da Madeira","Regi\227o Aut\243noma dos A\231ores","Santar\233m","Set\250bal","Viana do Castelo","Vila Real","Viseu","\201vora"]

-- %% [markdown]
-- ---
-- **Executa** a seguinte instrução para obteres a lista de `Município`s **pertencentes ao distrito de Lisboa**.
-- ```
-- municipios |> filter(\elem -> elem |> distrito |> (=="Lisboa"))
-- ```
-- A partir do seu resultado, obtém a **lista dos nomes** desses municípios.

-- %%
-- Out:
-- ["Alenquer","Amadora","Arruda dos Vinhos","Azambuja","Cadaval","Cascais","Lisboa","Loures","Lourinh\227","Mafra","Odivelas","Oeiras","Sintra","Sobral de Monte Agra\231o","Torres Vedras","Vila Franca de Xira"]

-- %% [markdown]
-- ---
-- A partir da lista que obtiveste na pergunta anterior, descobre **quantos habitantes** tem o distrito de Lisboa.

-- %%
-- Out:
-- 2250382
