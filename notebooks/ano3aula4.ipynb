-- %% [markdown]
-- © <b>2020-2024 ENSICO.</b> Todos os direitos reservados. <img src="../assets/copyright-icons.png" style="max-height:2em" />

-- %% [markdown]
-- <hr>
-- <span style="color:darkblue"> ⚠️ <b>IMPORTANTE</b></span>: <b>CORRE A CAIXA DE CÓDIGO SEGUINTE</b> para preparar a página.</span>

-- %%
import Prelude()
:opt no-lint
:l scripts/ensico.hs
done

-- %% [markdown]
-- <hr>

-- %% [markdown]
-- ### Strings (listas de caracteres)

-- %% [markdown]
-- Que instrução nos ajuda a saber **quantos caracteres** tem a seguinte string?

-- %%
"Eu sei muito disto!" |>

-- %% [markdown]
-- Que instrução nos ajuda a saber **quantas palavras** tem a seguinte string?

-- %%
"Eu sei muito disto!" |>

-- %% [markdown]
-- ### Listas, listas, listas...
-- Indica o **tipo dos elementos** de cada uma das seguintes listas.
--
-- <ul style="font-size:16px">
--     <li style="margin-bottom:20px"><code style="font-size:20px">[1,2,3,4,5]</code> é uma lista de __________________________________________</li>
--     <li style="margin-bottom:20px"><code style="font-size:20px">['a','b','c','d','e']</code> é uma lista de __________________________________________</li>
--     <li style="margin-bottom:20px"><code style="font-size:20px">"abcde"</code> é uma lista de __________________________________________</li>
--     <li style="margin-bottom:20px"><code style="font-size:20px">[ [1,2,3], [4,5], [6,7,8,9] ]</code> é uma lista de __________________________________________</li>
--     <li style="margin-bottom:20px"><code style="font-size:20px">[ (1,'a'), (2,'b'), (3,'c') ]</code> é uma lista de __________________________________________</li>
--     <li style="margin-bottom:20px"><code style="font-size:20px">[ "lula", "alga", "peixe" ]</code> é uma lista de __________________________________________</li>
--     <li style="margin-bottom:20px"><code style="font-size:20px">12345</code> é uma lista de __________________________________________</li>
-- </ul>

-- %% [markdown]
-- **Sublinha cada elemento** dessas listas e, acima de cada um, **escreve a sua posição**.

-- %% [markdown]
-- Qual é o **resultado** destas instruções?

-- %%
nums = [ [1,2,3], [4,5], [6,7,8,9] ]

-- %%
nums |> length

-- %%
nums |> reverse

-- %%
nums |> last

-- %%
nums |> map length

-- %%
nums |> map reverse

-- %%
nums |> map last

-- %% [markdown]
-- ## Página 2
-- Qual é o **resultado** destas instruções?

-- %%
strs = [ "lula", "alga", "peixe" ]

-- %%
strs |> length

-- %%
strs |> reverse

-- %%
strs |> last

-- %%
strs |> map length

-- %%
strs |> map reverse

-- %%
strs |> map last

-- %% [markdown]
-- ### Junção e Emparelhamento
-- Completa cada instrução com **`++` ou `#`**.

-- %%
[2,5,3]     [3,2,2,4,1]
-- Out:
-- [2,5,3,3,2,2,4,1]

-- %%
"abacaxi"     "doce"
-- Out:
-- "abacaxidoce"

-- %%
["kiwi","uva","banana"]     ["verde","roxo"]
-- Out:
-- ["kiwi","uva","banana","verde","roxo"]

-- %%
[2,5,3]     [3,2,2,4,1]
-- Out:
-- [(2,3),(5,2),(3,2)]

-- %%
"abacaxi"     "doce"
-- Out:
-- [('a','d'),('b','o'),('a','c'),('c','e')]

-- %% [markdown]
-- <br>
-- Qual é o <b>resultado</b> destas instruções?

-- %%
["kiwi","uva","banana"] # ["verde","roxo"]

-- %%
["kiwi","uva","banana"] ++ [2,5,3,0]

-- %%
[3,2,2,4,1] ++ []

-- %%
["kiwi","uva","banana"] # [2,5,3,0]

-- %%
[3,2,2,4,1] # []
