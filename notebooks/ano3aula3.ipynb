-- %% [markdown]
-- © <b>2020-2024 ENSICO.</b> Todos os direitos reservados. <img src="../assets/copyright-icons.png" style="max-height:2em" />

-- %% [markdown]
-- <hr>
-- <span style="color:darkblue"> ⚠️ <b>IMPORTANTE</b></span>: <b>CORRE A CAIXA DE CÓDIGO SEGUINTE</b> para preparar a página.</span>

-- %%
import Prelude()
:opt no-lint
:l scripts/ensico.hs
done

-- %% [markdown]
-- <hr>

-- %% [markdown]
-- ### Números
-- Qual é o **resultado** destas instruções?

-- %%
2 |> (+4) |> (*3)

-- %%
2 |> (*3) |> (+4)

-- %% [markdown]
-- ### Listas Numéricas

-- %% [markdown]
-- **Corrige** as seguintes listas.

-- %%
[45.2314.867.345

-- %%
(340,66,29,)

-- %%
[45,"ui",8,20]

-- %% [markdown]
-- <p>Quais destes <b>identificadores</b> podem ser dados a uma lista?</p>
-- <p style="font-size:20px; line-height: 2.5em; text-align:center"><code>minhalista</code>
-- <br><code>minhaLista</code>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;<code>MinhaLista</code>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
-- <code>MINHA_LISTA</code>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
-- <code>mInHaLiStA</code>
-- <br><code>minha.lista</code>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
-- <code>minha_lista</code>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
-- <code>minha-Lista</code>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
-- <code>minha lista</code>
-- <br><code>m1nh4l1574</code>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
-- <code>míñhãlîstà</code>&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;
-- <code>miñhaLis7a</code>
-- </p>

-- %% [markdown]
-- Escreve a instrução para dar o **identificador** `li` à lista `[1,2,3,4,5]`.

-- %%
li
-- Out:
-- [1,2,3,4,5]

-- %% [markdown]
-- ---
-- ## Página 2

-- %%
grandeListaNumerica = [ 576704, 576704, 16, 804, 375, 133419, 148954, 402455, 105091, 348200, 859281, 105356, 877550, 947222, 15, 15, 375094, 307944, 511017, 845, 527126, 37667, 688149, 551911, 908512, 797584, 930974, 308110, 454235, 511017, 831243, 193937]

-- %% [markdown]
-- **Completa** as instruções para obter os seguintes resultados:

-- %%
grandeListaNumerica |>
-- Out:
-- 32

-- %%
grandeListaNumerica |>
-- Out:
-- 13017526

-- %%
grandeListaNumerica |>
-- Out:
-- 947222

-- %%
grandeListaNumerica |>
-- Out:
-- [193937,831243,511017,454235,308110,930974,797584,908512,551911,688149,37667,527126,845,511017,307944,375094,15,15,947222,877550,105356,859281,348200,105091,402455,148954,133419,375,804,16,576704,576704]

-- %%
grandeListaNumerica |>
-- Out:
-- [15,15,16,375,804,845,37667,105091,105356,133419,148954,193937,307944,308110,348200,375094,402455,454235,511017,511017,527126,551911,576704,576704,688149,797584,831243,859281,877550,908512,930974,947222]

-- %%
grandeListaNumerica |>
-- Out:
-- [576704,16,804,375,133419,148954,402455,105091,348200,859281,105356,877550,947222,15,375094,307944,511017,845,527126,37667,688149,551911,908512,797584,930974,308110,454235,831243,193937]

-- %%
grandeListaNumerica |>
-- Out:
-- [576706,576706,18,806,377,133421,148956,402457,105093,348202,859283,105358,877552,947224,17,17,375096,307946,511019,847,527128,37669,688151,551913,908514,797586,930976,308112,454237,511019,831245,193939]

-- %%
grandeListaNumerica |>
-- Out:
-- [947222,930974,908512,877550,859281,831243,797584,688149,576704,576704,551911,527126,511017,511017,454235,402455,375094,348200,308110,307944,193937,148954,133419,105356,105091,37667,845,804,375,16,15,15]
